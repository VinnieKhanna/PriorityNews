# %%
import pandas as pd
import spacy
import numpy as np

data = pd.read_csv('fnn_train.csv')

# %%
# Create an empty model
nlp = spacy.blank("en")

# Create the TextCategorizer with exclusive classes and "bow" architecture
textcat = nlp.create_pipe(
              "textcat",
              config={
                "exclusive_classes": True,
                "architecture": "bow"})

# Add the TextCategorizer to the empty model
nlp.add_pipe(textcat)

# Add labels to text classifier
textcat.add_label("real")
textcat.add_label("fake")
# Out:
# 1

# %%
train_texts = data['paragraph_based_content'].values
train_labels = [{'cats': {'real': label == 'real',
                          'fake': label == 'fake'}} 
                for label in data['label_fnn']]

train_data = list(zip(train_texts, train_labels))

# %%
from spacy.util import minibatch

spacy.util.fix_random_seed(1)
optimizer = nlp.begin_training()

# Create the batch generator with batch size = 8
batches = minibatch(train_data, size=8)
# Iterate through minibatches
for batch in batches:
    # Each batch is a list of (text, label) but we need to
    # send separate lists for texts and labels to update().
    # This is a quick way to split a list of tuples into lists
    texts, labels = zip(*batch)
    nlp.update(texts, labels, sgd=optimizer)

import random

random.seed(1)
spacy.util.fix_random_seed(1)
optimizer = nlp.begin_training()

losses = {}
for epoch in range(10):
    random.shuffle(train_data)
    # Create the batch generator with batch size = 8
    batches = minibatch(train_data, size=8)
    # Iterate through minibatches
    for batch in batches:
        # Each batch is a list of (text, label) but we need to
        # send separate lists for texts and labels to update().
        # This is a quick way to split a list of tuples into lists
        texts, labels = zip(*batch)
        nlp.update(texts, labels, sgd=optimizer, losses=losses)
    print(losses)
# Out:
# {'textcat': 14.425886104354035}
# {'textcat': 25.676457950253678}
# {'textcat': 35.43259564392383}
# {'textcat': 43.84034698335879}
# {'textcat': 51.29761679176484}
# {'textcat': 57.54454548172815}
# {'textcat': 63.27015254911553}
# {'textcat': 68.2732394357406}
# {'textcat': 72.43486978944189}
# {'textcat': 76.4809805360849}

# %%
def predict(nlp, texts):
    # Use the tokenizer to tokenize each input text example
    docs = [nlp.tokenizer(text) for text in texts]

    # Use textcat to get the scores for each doc
    textcat = nlp.get_pipe('textcat')
    scores, _ = textcat.predict(docs)

    # From the scores, find the class with the highest score/probability
    predicted_class = scores.argmax(axis=1)

    return predicted_class

# %%
def evaluate(model, texts, labels):
    # Get predictions from textcat model
    predicted_class = predict(model, texts)

    # From labels, get the true class as a list of integers (POSITIVE -> 1, NEGATIVE -> 0)
    true_class = [0 if label == 'real' else 1 for label in labels]

    # A boolean or int array indicating correct predictions
    correct_predictions = predicted_class == true_class

    # The accuracy, number of correct predictions divided by all predictions
    accuracy = correct_predictions.mean()

    return accuracy

# %%
test_data = pd.read_csv('fnn_dev.csv')
test_texts = data.iloc[:, -2]
test_labels = data.iloc[:, -1]

accuracy = evaluate(nlp, test_texts, test_labels)
print(f"Loss: {losses['textcat']:.3f} \t Accuracy: {accuracy:.3f}")
# Out:
# Loss: 76.481 	 Accuracy: 0.854

# %%
texts = test_texts.iloc[454:464]
docs = [nlp.tokenizer(text) for text in texts]

# Use textcat to get the scores for each doc
textcat = nlp.get_pipe('textcat')
scores, _ = textcat.predict(docs)

print(scores)
# Out:
# [[1.0000000e+00 6.5678621e-12]
#  [1.0000000e+00 1.9356144e-12]
#  [9.3412977e-12 1.0000000e+00]
#  [1.8524821e-06 9.9999809e-01]
#  [1.0000000e+00 1.4809468e-14]
#  [1.0000000e+00 3.6570100e-08]
#  [2.1528252e-04 9.9978477e-01]
#  [9.9693632e-01 3.0637255e-03]
#  [1.0000000e+00 1.2133555e-08]
#  [1.0000000e+00 6.4267618e-13]]

# %%
# From the scores, find the label with the highest score/probability
predicted_labels = scores.argmax(axis=1)
print([textcat.labels[label] for label in predicted_labels])
print(test_labels.iloc[454:464])
# Out:
# ['real', 'real', 'fake', 'fake', 'real', 'real', 'fake', 'real', 'real', 'real']
# 454    real
# 455    real
# 456    fake
# 457    fake
# 458    real
# 459    real
# 460    fake
# 461    real
# 462    real
# 463    real
# Name: label_fnn, dtype: object

# %%
ranked_articles = pd.read_csv('article_ranking_data.csv')

texts = ranked_articles.iloc[:, 1]
docs = [nlp.tokenizer(text) for text in texts]

# Use textcat to get the scores for each doc
textcat = nlp.get_pipe('textcat')
scores, _ = textcat.predict(docs)
# Out:
# [[0.58112293 0.41887707]
#  [0.53663796 0.463362  ]]
# 0      Skip to:Main ContentSite NavigationSite foot...
# 1    Skip to main content\n  The Guardian - Back to...
# Name: article_text, dtype: object

# %%
import datetime
import numpy
import math

class Article:
    def __init__(self, url, publishedAt, readability):
        self.url = url
        self.publishedAt = publishedAt

        if readability <= 55:
            self.readabilityScore = 15 - (55 - readability)
        elif readability > 55 and readability <= 75:
            self.readabilityScore = 15
        elif readability > 75:
            self.readabilityScore = 15 - (readability - 75)

        now = datetime.datetime.utcnow()
        year = int(publishedAt[0:4])
        month = int(publishedAt[5:7])
        day = int(publishedAt[8:10])
        hour = int(publishedAt[11:13])
        minute = int(publishedAt[14:16])
        second = int(publishedAt[17:19])
        publishDateTime = datetime.datetime(year, month, day, hour, minute, second) #2020-10-17T20:40:13Z
        self.timeSincePublished = (now - publishDateTime).total_seconds() / 3600
        self.realProb = 0
        self.rankScore = 0

    def setRealProb(self, realProbability):
        self.realProb = realProbability

    def equateRank(self):
        real = self.realProb
        readability = self.readabilityScore
        time = self.timeSincePublished
        self.rankScore = real * real * readability * 3 * ((numpy.arctan(-1.2 * (time/24 - 3))) + 3 * math.pi/2)

# %%
# Press Shift+F10 to execute it or replace it with your code.
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.

import datetime
import readability
import json
from newsapi import NewsApiClient
import requests
from urllib.request import urlopen, Request
from urllib import error
from bs4 import BeautifulSoup
from sortedcontainers import SortedDict
from inscriptis import get_text
import pandas as pd
#import Article

# Init
newsapi = NewsApiClient(api_key='fb11d84c123e491983028590e5bdd0e6')

# /v2/top-headlines
health_headlines = newsapi.get_top_headlines(country='au',
                                          page_size=70, page=1, category='health')
general_headlines = newsapi.get_top_headlines(country='au',
                                          page_size=70, page=1, category='general')


# /v2/everything
# all_articles = newsapi.get_everything(q='politics',
#                                       from_param=date.today(),
#                                       language='en', page_size=10, page=2)
#
# # /v2/sources
# sources = newsapi.get_sources()
#print(json.dumps(all_articles, indent=6))


sd = SortedDict()
newsList = []    #actual unordered return list
textList = []


print("# Health Articles: " + str(health_headlines['totalResults']))
print("# General Articles: " + str(general_headlines['totalResults']))

all_headlines = health_headlines['articles'] + general_headlines['articles']
i = 0

for article in all_headlines:
    i += 1
    print(str(i) + ". " + article['url'])
    url = Request(article['url'], headers={'User-Agent': 'Mozilla/5.0'})

    html = None
    try:
        html = urlopen(url)
    except OSError:
        continue

    if "nytimes" in article['url'] or "wsj" in article['url'] or "news.google.com" in article['url'] or "subscribe" in article['url']:
        continue

    soup = BeautifulSoup(html, "html.parser")
    decoding = soup.original_encoding

    decoded = urlopen(url).read().decode(decoding)
    text = get_text(decoded)

    if len(text) < 100:
        continue

    newText = text.replace('*', '').replace('+', '')
    if len(text) > 10000:
        newText = newText[4000:len(newText) - 4000]
    elif len(text) > 5000:
        newText = newText[2000:len(newText) - 2000]
    elif len(text) > 2000:
        newText = newText[800:len(newText) - 800]
    elif len(text) > 1000:
        newText = newText[400:len(newText) - 400]

    textList.append(newText)

    readingStats = readability.getmeasures(text, lang='en')
    fleschScore = readingStats['readability grades']['FleschReadingEase']

    sd[fleschScore] = article['url']

    newArticle = Article(article['url'], article['publishedAt'], fleschScore)

    if newArticle not in newsList:
        newsList.append(newArticle)
    else:
        continue


i = 1

#print("\nlength: " + str(len(sd.keys())))
#for key in sd:
    #print(str(i) + ". " + sd[key] + ": " + str(key))
    #i += 1


#print("result lengths:")
#print(len(all_headlines))
# print(len(newsList))
#for news in newsList:
    #print("URL: " + news.url + " |Date: " + news.publishedAt + " |Readability: " + str(news.readabilityScore))

# url_list = pd.Series(urlList, name='url')
# text_list = pd.Series(textList, name='article_text')
#
# df = pd.merge(url_list, text_list, left_index=True, right_index=True)
# df.to_csv('article_ranking_data.csv')

# print(textList[1])
# print(datetime.datetime.utcnow())
# print(newsList[0].timeSincePublished)
# print(newsList[1].timeSincePublished)

#url_list = pd.Series(urlList, name='url')
ranked_articles = pd.DataFrame(textList)

#ranked_articles = pd.merge(url_list, text_list, left_index=True, right_index=True)
#ranked_articles.to_csv('article_ranking_data_2.csv')

texts = ranked_articles.iloc[:, 0]
docs = [nlp.tokenizer(text) for text in texts]

# Use textcat to get the scores for each doc
textcat = nlp.get_pipe('textcat')
scores, _ = textcat.predict(docs)
#print(scores)

# From the scores, find the label with the highest score/probability
predicted_labels = scores.argmax(axis=1)
print([textcat.labels[label] for label in predicted_labels])

for i in range(len(newsList)):
    newsList[i].setRealProb(scores[i][0])

for news in newsList:
    if news.realProb < .001:
        newsList.remove(news)

for news in newsList:
    news.equateRank()
    
newsList.sort(key=lambda newsArticle: newsArticle.rankScore, reverse=True)
j = 1
for news in newsList:
    print(str(j) + '. URL: ' + news.url + '\nScore: ' + str(news.rankScore))
    j = j + 1
# Out:
# # Health Articles: 70
# # General Articles: 38
# 1. https://amp.theguardian.comworld/2020/oct/18/coronavirus-test-results-must-come-in-24-hours-says-sage-scientist
# 2. https://greekcitytimes.com/2020/10/18/80844/
# 3. https://amp.theguardian.comlifeandstyle/2020/oct/18/masked-monsters-and-socially-distanced-spooks-celebrating-halloween-at-home
# 4. https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9dFUxNXFnM0dNZGfSAQA?oc=5
# 5. https://alkhaleejtoday.co/international/5124720/Covid-19-could-also-cause-sudden-and-permanent-hearing-loss.html
# 6. https://www.news.com.au/lifestyle/health/health-problems/mum-reveals-innocent-symptom-she-ignored-that-turned-out-to-be-lung-cancer/news-story/b31c822d7d4ac4a74c704611488f28f7
# 7. https://www.theaustralian.com.au/subscribe/news/1/
# 8. https://au.news.yahoo.com/nsw-womans-shock-diagnosis-after-losing-six-babies-024419790.html
# 9. https://alkhaleejtoday.co/international/5123468/The-flu-vaccine-suffers-from-corona-and-misinformation-on-the-Internet.html
# 10. https://www.news.com.au/world/coronavirus/health/influencer-33-who-thought-covid-didnt-exist-dies-after-catching-the-virus/news-story/56dc92f704419cf0bcd2bf8f9ef4392d
# 11. https://www.bbc.com/news/business-54572668
# 12. https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9Vm1JZnhIMUFxR2fSAQA?oc=5
# 13. http://www.china.org.cn/world/Off_the_Wire/2020-10/18/content_76816883.htm
# 14. https://www.9news.com.au/world/coronavirus-us-cases-surge-to-highest-levels-since-july-ten-states-have-record-infections/0d7813ed-4f30-4650-b0dc-a3bba297d680
# 15. https://www.eonline.com/news/1199447/influencer-dmitriy-stuzhuk-dead-of-coronavirus-after-telling-followers-it-wasnt-real
# 16. https://menafn.com/1100972942/Study-Regular-morning-exercise-may-cut-cancer-risk
# 17. https://alkhaleejtoday.co/coronavirus-news/5120154/Therapeutic-cattle-Cow-hug-is-now-a-supposedly-effective-way.html
# 18. https://www.colliemail.com.au/story/6973173/wa-frustrated-with-repeated-ship-outbreaks/?cs=9397
# 19. http://www.china.org.cn/world/Off_the_Wire/2020-10/18/content_76816722.htm
# 20. https://alkhaleejtoday.co/coronavirus-news/5119970/China%E2%80%99s-COVID-19-Vaccine-Is-Safe-And-Boosts-Antibody-Response-Lancet-Study.html
# 21. https://amp.theguardian.comscience/2020/oct/17/curing-the-incurable-ovarian-cancer-max-perutz-science-writing-award-2020-winner
# 22. https://alkhaleejtoday.co/international/5119144/Dexamethasone-is-the-only-effective-therapy-against-Covid-19-says-WHO.html
# 23. https://alkhaleejtoday.co/coronavirus-news/5119038/Latest-news-from-all-over-the-world.html
# 24. https://alkhaleejtoday.co/coronavirus-news/5118560/How-to-Reduce-Human-Suffering-3-Lessons-from-a-Groundbreaking-Public.html
# 25. https://alkhaleejtoday.co/coronavirus-news/5118308/Experimental-therapy-could-eliminate-the-need-for-insulin.html
# 26. https://upnewsinfo.com/2020/10/17/aussie-living-with-cerebral-palsy-gives-a-new-perspective-on-life-in-lockdown/
# 27. https://www.adelaidenow.com.au/subscribe/news/1/
# 28. https://alkhaleejtoday.co/coronavirus-news/5117808/China-is-expanding-the-circle-of-people-receiving-experimental-Covid-19-vaccines.html
# 29. https://alkhaleejtoday.co/coronavirus-news/5117806/Best-Supplements-For-High-Blood-Pressure-Prevent-High-Blood-Pressure-Symptoms.html
# 30. https://washingtonnewsday.com/health/who-on-rising-corona-cases-in-europe-not-to-be-neglected/
# 31. https://www.townsvillebulletin.com.au/subscribe/news/1/
# 32. https://thenewdaily.com.au/life/wellbeing/2020/10/17/weighted-blankets-anxiety-science/
# 33. https://alkhaleejtoday.co/coronavirus-news/5116908/Antibodies-Fade-Quickly-in-Recovery-of-Covid-19-Patients-Study.html
# 34. https://www.zmescience.com/science/men-and-women-are-responding-differently-to-the-pandemic-heres-how/
# 35. https://micky.com.au/cats-carry-diseases-that-can-be-deadly-to-humans-and-its-costing-australia-6-billion-every-year/
# 36. https://www.ntnews.com.au/subscribe/news/1/
# 37. http://www.daijiworld.com/news/newsDisplay.aspx?newsID=761934
# 38. https://afinancebroker.com/index.php/2020/10/17/can-supplements-really-help-fight-covid-19-heres-what-we-know-and-dont-know/
# 39. https://www.sheppnews.com.au/virus-updates/2020/10/16/1782763/heres-where-you-can-be-tested-this-weekend-for-covid-19
# 40. https://alkhaleejtoday.co/international/5114178/Rare-COVID-19-Complications-Among-Adults-in-Minority-Groups.html
# 41. https://alkhaleejtoday.co/coronavirus-news/5114006/New-blood-test-predicts-which-COVID-patients-are-at-high-risk.html
# 42. https://www.popsugar.com.au/fitness/spinco-coronavirus-outbreak-hamilton-ontario-47892960
# 43. https://micky.com.au/covid-19-has-a-lasting-impact-on-health/
# 44. https://7news.com.au/lifestyle/health-wellbeing/heather-cramer-41-shares-unusual-breast-cancer-sign--c-1401221
# 45. https://menafn.com/1100970750/Scientist-reveal-a-shocking-new-way-to-have-a-relaxing-life-The-Worlds-Best-Kept-Secret-Weapon-In-The-Relaxation-World
# 46. https://www.wjsu.org/post/coronavirus-faqs-open-windows-winter-holding-your-breath-sprayed-masks
# 47. https://alkhaleejtoday.co/coronavirus-news/5112688/Combating-multiple-sclerosis-with-a-plant-sugar.html
# 48. https://alkhaleejtoday.co/coronavirus-news/5112504/Long-Covid-can-be-at-least-four-different-syndromes-says-New-Review.html
# 49. https://www.healthline.com/health-news/is-fructose-linked-to-adhd-neurodevelopmental-disorders
# 50. https://www.sbs.com.au/news/nsw-reports-five-new-local-coronavirus-cases-as-testing-ramps-up-in-southwest-sydney
# 51. https://www.abc.net.au/news/2020-10-17/covidsafe-app-coronavirus-safe-effectiveness-news/12766024
# 52. https://www.eurekalert.org/pub_releases/2020-10/uoq-ffb101220.php
# 53. https://www.businessinsider.com.au/therapists-werent-allowed-to-join-nxivm-would-see-through-raniere-2020-10
# 54. https://www.news-medical.net/news/20201016/Objective-measures-reveal-a-higher-prevalence-of-smell-loss-in-COVID-19-patients.aspx
# 55. https://www.futurity.org/microbot-colon-flips-drug-delivery-2456492/
# 56. https://news.google.com/__i/rss/rd/articles/CBMiT2h0dHBzOi8vd3d3Lm1pcmFnZW5ld3MuY29tL2Nocm9uaWMtZGlzZWFzZS1wb29yLXB1YmxpYy1yZXNwb25zZS1mdWVscy1jb3ZpZC0xOS_SAQA?oc=5
# 57. https://thehealthmania.com/researchers-have-developed-a-new-tool-to-treat-melanoma/5968/
# 58. https://www.adelaidenow.com.au/subscribe/news/1/
# 59. https://news.google.com/__i/rss/rd/articles/CBMiUGh0dHBzOi8vd3d3Lm1pcmFnZW5ld3MuY29tL3ByaW1lLW1pbmlzdGVyLXMtc3RhdGVtZW50LW9uLWNvcm9uYXZpcnVzLTE3LW9jdG9iZXIv0gEA?oc=5
# 60. https://medicalxpress.com/news/2020-10-peptides-antibiotic-combination-result-effective.html
# 61. https://news.google.com/__i/rss/rd/articles/CBMiY2h0dHBzOi8vd3d3Lm1pcmFnZW5ld3MuY29tL3BpbnBvaW50aW5nLXNpbGVudC1tdXRhdGlvbnMtdGhhdC1nYXZlLWNvcm9uYXZpcnVzLWFuLWV2b2x1dGlvbmFyeS1lZGdlL9IBAA?oc=5
# 62. https://medicalxpress.com/news/2020-10-antibiotics.html
# 63. https://www.news-medical.net/news/20201016/African-women-use-advice-apps-to-improve-sexual-relationships-rather-than-health.aspx
# 64. https://www.news-medical.net/news/20201016/Jumping-genes-may-frequently-alter-neural-function.aspx
# 65. https://www.daijiworld.com/news/newsDisplay.aspx?newsID=761760
# 66. https://hackaday.com/tag/deep-brain-stimulation/
# 67. https://au.news.yahoo.com/covid-infections-latest-england-ons-111303029.html
# 68. https://www.medicalplasticsnews.com/news/dyadic-c1-protein-expression-platform-explored-in-fight-agai/
# 69. https://medicalxpress.com/news/2020-10-doc-donkey-therapy-eases-spain.html
# 70. https://alkhaleejtoday.co/international/5107040/Is-your-cat-making-you-sick-How-to-Prevent-Diseases.html
# 71. https://www.theage.com.au/sport/afl/brownlow-medal-2020-the-odds-red-carpet-fashion-favourities-smokies-and-club-by-club-voting-20201017-p5661s.html
# 72. https://www.news.com.au/travel/travel-updates/virgin-australia-changes-to-airline-set-to-shake-up-aussie-industry/news-story/e7413b7f6e16765652a7504869ea0305
# 73. https://www.sciencealert.com/multicellular-bacteria-traits-suggest-earliest-life-was-more-like-us-than-we-realised
# 74. https://www.sciencealert.com/coral-of-virtually-every-species-age-and-size-is-declining-in-the-great-barrier-reef
# 75. https://www.smh.com.au/sport/motorsport/red-bull-holden-s-van-gisbergen-triumphs-at-bathurst-20201018-p5668j.html
# 76. https://www.perthnow.com.au/entertainment/tv/actor-hugh-sheridan-opens-up-about-sexuality-says-he-has-been-with-men-and-women-ng-b881696492z
# 77. https://www.abc.net.au/news/2020-10-18/regional-victoria-coronavirus-restrictions-change-whats-allowed/12776468
# 78. https://www.news.com.au/world/coronavirus/closures/qld-election-2020-border-closure-decision-hated-by-20-million-aussies/news-story/c1c2aa884c29f3bbceeed5575fb0144c
# 79. https://www.techradar.com/news/why-the-iphone-11-is-a-better-buy-than-the-iphone-12
# 80. https://www.news.com.au/entertainment/celebrity-life/home-improvement-star-zachery-ty-bryan-arrested-for-allegedly-choking-his-girlfriend/news-story/846f9ef591c4f65dbe4a220653536200
# 81. https://amp.theguardian.comsport/2020/oct/18/bledisloe-cup-game-two-all-blacks-wallabies-match-report
# 82. https://www.theaustralian.com.au/subscribe/news/1/
# 83. https://www.theage.com.au/national/victoria/easing-of-restrictions-offers-mixed-fare-for-restaurants-20201018-p5667y.html
# 84. https://www.theguardian.com/world/2020/oct/18/jacinda-ardern-eases-into-second-term-amid-relief-in-new-zealand-at-election-landslide
# 85. https://www.theguardian.com/world/live/2020/oct/18/coronavirus-live-news-curfew-starts-for-millions-in-france-victoria-set-to-ease-restrictions
# 86. https://www.news.com.au/entertainment/tv/tv-shows/talking-heads-revival-harriet-walter-on-how-the-pandemic-series-was-made/news-story/eb49bda72f495648f45ee8a4613d7878
# 87. https://www.news.com.au/finance/business/melbourne-lockdown-daniel-andrews-eases-restrictions-but-businesses-miss-out/news-story/a76254fe7fa34e8364b2fa736d74934a
# 88. https://www.abc.net.au/news/2020-10-18/new-zealanders-fly-into-wa-under-travel-bubble-arrangement/12779978
# 89. https://www.smh.com.au/world/north-america/what-if-everyone-is-wrong-and-trump-wins-20201018-p5667f.html
# 90. https://www.news.com.au/national/victoria/news/coronavirus-australia-hairdresser-flouting-victorias-stage-4-restrictions-hit-with-10k-fine/news-story/a2ae589d209fe9e8773089d0f3cacf6f
# 91. https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9NFRXZlZoLUNaUWvSAQA?oc=5
# 92. https://micky.com.au/microsoft-extending-warranty-for-elite-series-2-controllers-over-joystick-drift-issue/
# 93. https://www.fool.com.au/2020/10/18/3-core-holdings-for-a-100000-asx-portfolio-18-october-2020/
# 94. https://www.dailymail.co.uk/tvshowbiz/article-8851571/Big-Brother-host-Sonia-Kruger-swaps-feels-flat-shoes-films-new-series.html
# 95. https://www.smh.com.au/national/nsw/five-new-cases-of-covid-19-in-nsw-including-four-in-hotel-quarantine-20201018-p5665u.html
# 96. https://www.news.com.au/world/coronavirus/health/influencer-33-who-thought-covid-didnt-exist-dies-after-catching-the-virus/news-story/56dc92f704419cf0bcd2bf8f9ef4392d
# 97. https://www.fool.com.au/2020/10/18/why-id-start-preparing-for-stock-market-crash-part-2-today/
# 98. https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9Vm1JZnhIMUFxR2fSAQA?oc=5
# 99. https://www.theage.com.au/national/victoria/which-covid-19-restrictions-are-likely-to-ease-today-20201018-p5664a.html
# 100. https://www.abc.net.au/news/2020-10-18/armenia-and-azerbaijan-agree-new-nagorno-karabakh-ceasefire/12779444
# 101. https://www.news.com.au/world/europe/paris-beheading-france-reacts-to-decapitation-of-samuel-paty/news-story/54ebe11b1d3920b29c5da9e1928ce334
# 102. https://www.gizmodo.com.au/2020/10/every-iphone-12-phone-plan-in-australia-pro-max-mini/
# 103. https://amp.theguardian.comaustralia-news/2020/oct/18/act-election-greens-to-push-for-policy-reset-after-labor-victory
# 104. https://www.9news.com.au/world/coronavirus-us-cases-surge-to-highest-levels-since-july-ten-states-have-record-infections/0d7813ed-4f30-4650-b0dc-a3bba297d680
# 105. https://www.sciencealert.com/graphene-reveals-a-super-rare-form-of-magnetism-when-3-layers-combine-together
# 106. https://micky.com.au/covid-19-has-a-lasting-impact-on-health/
# 107. https://www.gamespot.com/articles/best-deals-in-best-buys-early-black-friday-sale-games-4k-tvs-headsets-and-more-for-cheap/1100-6483117/
# 108. https://tass.com/science/1212039
# ['real', 'real', 'real', 'fake', 'fake', 'fake', 'real', 'fake', 'fake', 'real', 'fake', 'real', 'real', 'real', 'real', 'real', 'real', 'fake', 'real', 'real', 'fake', 'real', 'real', 'real', 'real', 'real', 'fake', 'real', 'fake', 'real', 'real', 'real', 'fake', 'fake', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'fake', 'fake', 'real', 'fake', 'fake', 'real', 'real', 'real', 'fake', 'fake', 'real', 'real', 'real', 'fake', 'real', 'real', 'real', 'real', 'fake', 'real', 'real', 'real', 'fake', 'real', 'fake', 'real', 'fake', 'real', 'real', 'fake', 'real', 'real', 'fake', 'fake', 'fake', 'real', 'fake', 'fake', 'fake', 'real', 'real', 'real', 'real']
# 1. URL: https://www.news.com.au/travel/travel-updates/virgin-australia-changes-to-airline-set-to-shake-up-aussie-industry/news-story/e7413b7f6e16765652a7504869ea0305
# Score: 269.968756139931
# 2. URL: https://www.theage.com.au/national/victoria/easing-of-restrictions-offers-mixed-fare-for-restaurants-20201018-p5667y.html
# Score: 269.4978058106405
# 3. URL: https://www.theguardian.com/world/2020/oct/18/jacinda-ardern-eases-into-second-term-amid-relief-in-new-zealand-at-election-landslide
# Score: 269.4755768099971
# 4. URL: https://micky.com.au/microsoft-extending-warranty-for-elite-series-2-controllers-over-joystick-drift-issue/
# Score: 268.8109166129149
# 5. URL: https://www.dailymail.co.uk/tvshowbiz/article-8851571/Big-Brother-host-Sonia-Kruger-swaps-feels-flat-shoes-films-new-series.html
# Score: 268.7133562694339
# 6. URL: https://www.bbc.com/news/business-54572668
# Score: 268.4000387019615
# 7. URL: https://www.abc.net.au/news/2020-10-18/armenia-and-azerbaijan-agree-new-nagorno-karabakh-ceasefire/12779444
# Score: 268.2498411241669
# 8. URL: https://www.colliemail.com.au/story/6973173/wa-frustrated-with-repeated-ship-outbreaks/?cs=9397
# Score: 266.72218937200597
# 9. URL: https://alkhaleejtoday.co/coronavirus-news/5118308/Experimental-therapy-could-eliminate-the-need-for-insulin.html
# Score: 265.5565995683295
# 10. URL: https://thenewdaily.com.au/life/wellbeing/2020/10/17/weighted-blankets-anxiety-science/
# Score: 265.0904480810678
# 11. URL: https://www.zmescience.com/science/men-and-women-are-responding-differently-to-the-pandemic-heres-how/
# Score: 264.18762501709875
# 12. URL: https://micky.com.au/cats-carry-diseases-that-can-be-deadly-to-humans-and-its-costing-australia-6-billion-every-year/
# Score: 264.05018390457985
# 13. URL: https://alkhaleejtoday.co/international/5119144/Dexamethasone-is-the-only-effective-therapy-against-Covid-19-says-WHO.html
# Score: 263.77838813055774
# 14. URL: https://afinancebroker.com/index.php/2020/10/17/can-supplements-really-help-fight-covid-19-heres-what-we-know-and-dont-know/
# Score: 262.4643664528513
# 15. URL: https://micky.com.au/covid-19-has-a-lasting-impact-on-health/
# Score: 260.52813930165723
# 16. URL: https://micky.com.au/covid-19-has-a-lasting-impact-on-health/
# Score: 260.5153657148839
# 17. URL: https://www.news.com.au/world/coronavirus/closures/qld-election-2020-border-closure-decision-hated-by-20-million-aussies/news-story/c1c2aa884c29f3bbceeed5575fb0144c
# Score: 260.1893254774817
# 18. URL: https://alkhaleejtoday.co/coronavirus-news/5112688/Combating-multiple-sclerosis-with-a-plant-sugar.html
# Score: 259.74078950681974
# 19. URL: https://www.healthline.com/health-news/is-fructose-linked-to-adhd-neurodevelopmental-disorders
# Score: 259.2102904294172
# 20. URL: https://www.sbs.com.au/news/nsw-reports-five-new-local-coronavirus-cases-as-testing-ramps-up-in-southwest-sydney
# Score: 259.1319790079517
# 21. URL: https://alkhaleejtoday.co/international/5114178/Rare-COVID-19-Complications-Among-Adults-in-Minority-Groups.html
# Score: 258.97396525839645
# 22. URL: https://www.businessinsider.com.au/therapists-werent-allowed-to-join-nxivm-would-see-through-raniere-2020-10
# Score: 257.12501639532826
# 23. URL: https://www.eurekalert.org/pub_releases/2020-10/uoq-ffb101220.php
# Score: 255.8529636924773
# 24. URL: https://thehealthmania.com/researchers-have-developed-a-new-tool-to-treat-melanoma/5968/
# Score: 255.8328747196367
# 25. URL: https://www.news-medical.net/news/20201016/African-women-use-advice-apps-to-improve-sexual-relationships-rather-than-health.aspx
# Score: 254.07978371328363
# 26. URL: https://www.wjsu.org/post/coronavirus-faqs-open-windows-winter-holding-your-breath-sprayed-masks
# Score: 252.11798171458264
# 27. URL: https://hackaday.com/tag/deep-brain-stimulation/
# Score: 250.33322278709295
# 28. URL: https://www.sciencealert.com/graphene-reveals-a-super-rare-form-of-magnetism-when-3-layers-combine-together
# Score: 246.40396476912164
# 29. URL: https://alkhaleejtoday.co/international/5124720/Covid-19-could-also-cause-sudden-and-permanent-hearing-loss.html
# Score: 244.99827680815937
# 30. URL: https://www.news-medical.net/news/20201016/Objective-measures-reveal-a-higher-prevalence-of-smell-loss-in-COVID-19-patients.aspx
# Score: 239.3647269968285
# 31. URL: https://alkhaleejtoday.co/coronavirus-news/5112504/Long-Covid-can-be-at-least-four-different-syndromes-says-New-Review.html
# Score: 222.0970967730898
# 32. URL: http://www.china.org.cn/world/Off_the_Wire/2020-10/18/content_76816722.htm
# Score: 219.45994637000436
# 33. URL: https://www.smh.com.au/sport/motorsport/red-bull-holden-s-van-gisbergen-triumphs-at-bathurst-20201018-p5668j.html
# Score: 217.1131761879281
# 34. URL: https://alkhaleejtoday.co/coronavirus-news/5119970/China%E2%80%99s-COVID-19-Vaccine-Is-Safe-And-Boosts-Antibody-Response-Lancet-Study.html
# Score: 210.56328535990863
# 35. URL: https://www.abc.net.au/news/2020-10-18/new-zealanders-fly-into-wa-under-travel-bubble-arrangement/12779978
# Score: 209.2839651265924
# 36. URL: https://www.news.com.au/entertainment/tv/tv-shows/talking-heads-revival-harriet-walter-on-how-the-pandemic-series-was-made/news-story/eb49bda72f495648f45ee8a4613d7878
# Score: 205.62461943656066
# 37. URL: https://www.news.com.au/national/victoria/news/coronavirus-australia-hairdresser-flouting-victorias-stage-4-restrictions-hit-with-10k-fine/news-story/a2ae589d209fe9e8773089d0f3cacf6f
# Score: 197.79071983305332
# 38. URL: https://www.news.com.au/entertainment/celebrity-life/home-improvement-star-zachery-ty-bryan-arrested-for-allegedly-choking-his-girlfriend/news-story/846f9ef591c4f65dbe4a220653536200
# Score: 195.97304596902063
# 39. URL: https://www.futurity.org/microbot-colon-flips-drug-delivery-2456492/
# Score: 194.62934073829285
# 40. URL: https://upnewsinfo.com/2020/10/17/aussie-living-with-cerebral-palsy-gives-a-new-perspective-on-life-in-lockdown/
# Score: 181.07125433599074
# 41. URL: https://alkhaleejtoday.co/coronavirus-news/5116908/Antibodies-Fade-Quickly-in-Recovery-of-Covid-19-Patients-Study.html
# Score: 178.48228232598504
# 42. URL: https://www.perthnow.com.au/entertainment/tv/actor-hugh-sheridan-opens-up-about-sexuality-says-he-has-been-with-men-and-women-ng-b881696492z
# Score: 173.51961416876262
# 43. URL: https://alkhaleejtoday.co/coronavirus-news/5114006/New-blood-test-predicts-which-COVID-patients-are-at-high-risk.html
# Score: 172.5357674572765
# 44. URL: https://tass.com/science/1212039
# Score: 171.71311889914097
# 45. URL: https://www.smh.com.au/national/nsw/five-new-cases-of-covid-19-in-nsw-including-four-in-hotel-quarantine-20201018-p5665u.html
# Score: 168.81015974049754
# 46. URL: https://www.news.com.au/lifestyle/health/health-problems/mum-reveals-innocent-symptom-she-ignored-that-turned-out-to-be-lung-cancer/news-story/b31c822d7d4ac4a74c704611488f28f7
# Score: 152.53191059347125
# 47. URL: https://alkhaleejtoday.co/coronavirus-news/5120154/Therapeutic-cattle-Cow-hug-is-now-a-supposedly-effective-way.html
# Score: 140.004063325374
# 48. URL: https://greekcitytimes.com/2020/10/18/80844/
# Score: 138.65927440300663
# 49. URL: https://www.sciencealert.com/multicellular-bacteria-traits-suggest-earliest-life-was-more-like-us-than-we-realised
# Score: 137.6069554504514
# 50. URL: https://au.news.yahoo.com/covid-infections-latest-england-ons-111303029.html
# Score: 134.19027327026316
# 51. URL: https://www.medicalplasticsnews.com/news/dyadic-c1-protein-expression-platform-explored-in-fight-agai/
# Score: 130.98767849597567
# 52. URL: https://www.abc.net.au/news/2020-10-17/covidsafe-app-coronavirus-safe-effectiveness-news/12766024
# Score: 100.17920027800186
# 53. URL: https://alkhaleejtoday.co/coronavirus-news/5117806/Best-Supplements-For-High-Blood-Pressure-Prevent-High-Blood-Pressure-Symptoms.html
# Score: 95.17454974239266
# 54. URL: https://www.theage.com.au/sport/afl/brownlow-medal-2020-the-odds-red-carpet-fashion-favourities-smokies-and-club-by-club-voting-20201017-p5661s.html
# Score: 83.03612327190369
# 55. URL: https://www.abc.net.au/news/2020-10-18/regional-victoria-coronavirus-restrictions-change-whats-allowed/12776468
# Score: 68.63154372654643
# 56. URL: http://www.china.org.cn/world/Off_the_Wire/2020-10/18/content_76816883.htm
# Score: 54.608032224801335
# 57. URL: https://alkhaleejtoday.co/coronavirus-news/5119038/Latest-news-from-all-over-the-world.html
# Score: 44.19207510393859
# 58. URL: https://www.sciencealert.com/coral-of-virtually-every-species-age-and-size-is-declining-in-the-great-barrier-reef
# Score: 35.44462557717664
# 59. URL: https://au.news.yahoo.com/nsw-womans-shock-diagnosis-after-losing-six-babies-024419790.html
# Score: 13.044712635682508
# 60. URL: https://www.eonline.com/news/1199447/influencer-dmitriy-stuzhuk-dead-of-coronavirus-after-telling-followers-it-wasnt-real
# Score: 13.027460248390703
# 61. URL: https://www.news.com.au/finance/business/melbourne-lockdown-daniel-andrews-eases-restrictions-but-businesses-miss-out/news-story/a76254fe7fa34e8364b2fa736d74934a
# Score: 8.470408958040192
# 62. URL: https://alkhaleejtoday.co/international/5123468/The-flu-vaccine-suffers-from-corona-and-misinformation-on-the-Internet.html
# Score: 7.962247903740344
# 63. URL: https://www.news.com.au/world/coronavirus/health/influencer-33-who-thought-covid-didnt-exist-dies-after-catching-the-virus/news-story/56dc92f704419cf0bcd2bf8f9ef4392d
# Score: 4.216668153039187
# 64. URL: https://www.news.com.au/world/coronavirus/health/influencer-33-who-thought-covid-didnt-exist-dies-after-catching-the-virus/news-story/56dc92f704419cf0bcd2bf8f9ef4392d
# Score: 4.216522536550034
# 65. URL: https://menafn.com/1100970750/Scientist-reveal-a-shocking-new-way-to-have-a-relaxing-life-The-Worlds-Best-Kept-Secret-Weapon-In-The-Relaxation-World
# Score: 3.1096815421608937
# 66. URL: https://www.fool.com.au/2020/10/18/3-core-holdings-for-a-100000-asx-portfolio-18-october-2020/
# Score: 1.4012867632870913
# 67. URL: https://www.news-medical.net/news/20201016/Jumping-genes-may-frequently-alter-neural-function.aspx
# Score: 0.3551144441461916
# 68. URL: https://alkhaleejtoday.co/coronavirus-news/5117808/China-is-expanding-the-circle-of-people-receiving-experimental-Covid-19-vaccines.html
# Score: 0.26990084746076615
# 69. URL: https://www.smh.com.au/world/north-america/what-if-everyone-is-wrong-and-trump-wins-20201018-p5667f.html
# Score: 0.013309534338313476
# 70. URL: https://www.9news.com.au/world/coronavirus-us-cases-surge-to-highest-levels-since-july-ten-states-have-record-infections/0d7813ed-4f30-4650-b0dc-a3bba297d680
# Score: 0.0033691363013067114
# 71. URL: https://www.news.com.au/world/europe/paris-beheading-france-reacts-to-decapitation-of-samuel-paty/news-story/54ebe11b1d3920b29c5da9e1928ce334
# Score: 0.0032311445851529556
# 72. URL: https://medicalxpress.com/news/2020-10-antibiotics.html
# Score: 0.00131607997439886
# 73. URL: https://www.9news.com.au/world/coronavirus-us-cases-surge-to-highest-levels-since-july-ten-states-have-record-infections/0d7813ed-4f30-4650-b0dc-a3bba297d680
# Score: 0.0010778240345594098
# 74. URL: https://medicalxpress.com/news/2020-10-peptides-antibiotic-combination-result-effective.html
# Score: 0.0004777259003747043
# 75. URL: https://www.fool.com.au/2020/10/18/why-id-start-preparing-for-stock-market-crash-part-2-today/
# Score: 0.00046565099383264825
# 76. URL: https://alkhaleejtoday.co/international/5107040/Is-your-cat-making-you-sick-How-to-Prevent-Diseases.html
# Score: 1.915976969133754e-11
# 77. URL: https://www.gamespot.com/articles/best-deals-in-best-buys-early-black-friday-sale-games-4k-tvs-headsets-and-more-for-cheap/1100-6483117/
# Score: -83.92529934323045
